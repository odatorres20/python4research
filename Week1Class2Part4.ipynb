# %%
#RANGES: No convert in list is less usefull, range is optimal
range(5)
# Out:
# range(0, 5)

# %%
list(range(5))
# Out:
# [0, 1, 2, 3, 4]

# %%
list(range(1,6))
# Out:
# [1, 2, 3, 4, 5]

# %%
list(range(1,13,2))
# Out:
# [1, 3, 5, 7, 9, 11]

# %%
#STRINGS
#Inmutable sequences of characters
S= "Python"

# %%
len(S)
# Out:
# 6

# %%
S[-1]
# Out:
# 'n'

# %%
S[0]
# Out:
# 'P'

# %%
S[0:3]
# Out:
# 'Pyt'

# %%
S[-3:]
# Out:
# 'hon'

# %%
"y" in S
# Out:
# True

# %%
"Y" in S
# Out:
# False

# %%
#Polymorfism, the ojetc gonna do something in function 
#of the type o f data
12 + 12
# Out:
# 24

# %%
"Hello" + "Hello"
# Out:
# 'HelloHello'

# %%
S = "Phyton"

# %%
3*S
# Out:
# 'PhytonPhytonPhyton'

# %%
"Ocho es" + str(8)
# Out:
# 'Ocho es8'

# %%
dir(str)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
# ...

# %%
str.replace?
# Out:
# Signature: str.replace(self, old, new, count=-1, /)
# Docstring:
# Return a copy with all occurrences of substring old replaced by new.
#
#   count
#     Maximum number of occurrences to replace.
#     -1 (the default value) means replace all occurrences.
#
# If the optional argument count is given, only the first count occurrences are
# replaced.
# Type:      method_descriptor

# %%
name = "Tina Fey"

# %%
name.replace("T","t")
# Out:
# 'tina Fey'

# %%
newname=name.replace("T","t")

# %%
newname
# Out:
# 'tina Fey'

# %%
name
# Out:
# 'Tina Fey'

# %%
name = name.split(" ")

# %%
type(name)
# Out:
# list

# %%
len(name)
# Out:
# 2

# %%
name[0]
# Out:
# 'Tina'

# %%
name[1]
# Out:
# 'Fey'

# %%
type(name[0])
# Out:
# str

# %%
type(name[1])
# Out:
# str

# %%
name[0].upper()
# Out:
# 'TINA'

# %%
name[1].lower()
# Out:
# 'fey'

# %%
#FOUND SETS ON THE FIRST ipynb
#(Diferences between 2 sets)
#x.symmetric_difference(y) performs this task
#DICTIONARIES
#Dictionaries consists in Key: value pairs, 
#Keys are inmutable and values can be anything
#Dictionaries themselves are mutable
#Fast look up, do not mantain letf rigth order 
#You can be looping over the value of keys
age = {}

# %%
age = dict ()

# %%
age = {"Tin":29, "Jin": 31, "Pan": 27, "San":35}

# %%
age["Pan"]
# Out:
# 27

# %%
age["Tin"] = age["Tin"] + 1
age["Tin"]
# Out:
# 30

# %%
age["Tin"] += 1

# %%
age["Tin"]
# Out:
# 31

# %%
name = age.keys()

# %%
type(name)
# Out:
# dict_keys

# %%
age["Tom"] = 50

# %%
name
# Out:
# dict_keys(['Tin', 'Jin', 'Pan', 'San', 'Tom'])

# %%
ages= age.values()

# %%
ages
# Out:
# dict_values([50, 31, 27, 35, 50])

# %%
age["Nick"] = 31

# %%
name
# Out:
# dict_keys(['Tin', 'Jin', 'Pan', 'San', 'Tom', 'Nick'])

# %%
ages
# Out:
# dict_values([50, 31, 27, 35, 50, 31])

# %%
"Tom" in age
# Out:
# True

# %%
"Zofia" in age
# Out:
# False

# %%
#Only immutable types are allowed as keys.
