# %%
numbers = [2,3,4,8]

# %%
numbers[0]
# Out:
# 2

# %%
numbers[1]
# Out:
# 3

# %%
numbers[-1]
# Out:
# 8

# %%
numbers.append(10)

# %%
numbers
# Out:
# [2, 3, 4, 8, 10]

# %%
x = [12,14,16]

# %%
numbers + x
# Out:
# [2, 3, 4, 8, 10, 12, 14, 16]

# %%
type(_)
# Out:
# list

# %%
numbers = [1,3,5,7,11,13,15]

# %%
numbers.reverse()

# %%
#in place changes 
numbers
# Out:
# [15, 13, 11, 7, 5, 3, 1]

# %%
numbers
# Out:
# [15, 13, 11, 7, 5, 3, 1]

# %%
names = ["Sofia", "Ariel", "George", "Alex"]

# %%
names.sort()

# %%
names
# Out:
# ['Alex', 'Ariel', 'George', 'Sofia']

# %%
names.reverse()

# %%
names

# %%
sorted_names = sorted(names)

# %%
sorted_names

# %%
len(names)

# %%
len(sorted_names)
