# %%
#Tuples
#inmutables sequences for variation of data
T = (1,3,5,7)

# %%
len(T)
# Out:
# 4

# %%
T + (8,9,11)
# Out:
# (1, 3, 5, 7, 8, 9, 11)

# %%
T
# Out:
# (1, 3, 5, 7)

# %%
T[3]
# Out:
# 7

# %%
#Pack and unpack tuples
x = 12.34
y = 12.45
#As a tuple that cibist in two coordinate
coordinate = (x,y)

# %%
type(coordinate)
# Out:
# tuple

# %%
(c1, c2) = coordinate

# %%
c1
# Out:
# 12.34

# %%
coordinates = [(0,0),(0,1),(1,2),(2,4),(3,6),(4,8),(8,10),(10,12)]

# %%
coordinates
# Out:
# [(0, 0), (0, 1), (1, 2), (2, 4), (3, 6), (4, 8), (8, 10), (10, 12)]

# %%
for (x,y) in coordinates: 
    print (x,y)
# Out:
# 0 0
# 0 1
# 1 2
# 2 4
# 3 6
# 4 8
# 8 10
# 10 12

# %%
for x,y in coordinates:
    print (x,y)
# Out:
# 0 0
# 0 1
# 1 2
# 2 4
# 3 6
# 4 8
# 8 10
# 10 12

# %%
c = (2,3)

# %%
type(c)
# Out:
# tuple

# %%
c = (2)

# %%
type(c)
# Out:
# int

# %%
c = 2,

# %%
type(c)
# Out:
# tuple

# %%
c.count(2)
# Out:
# 1

# %%
sum(c)
# Out:
# 2

# %%
type ((2,))
# Out:
# tuple

# %%
#RANGES
range(5)
# Out:
# range(0, 5)

# %%
list(range(5))
#5 is the stopping value
# Out:
# [0, 1, 2, 3, 4]

# %%
list(range(1,6))
# Out:
# [1, 2, 3, 4, 5]

# %%
list(range(1,13,2))
# Out:
# [1, 3, 5, 7, 9, 11]

# %%
#Here is another point of difference between Python 2 and Python 3! Note that the Python 3 range object is a generator, similar to the Python 2 xrange object.  In contrast, the Python 2 range object is a list, which instantiates its elements
