# %%
#Objects
#Type:string,list, number
#Number and Identity
#Atributes: Data attibute and methods (functions)

# %%
import numpy as np

# %%
x = np.array([1,3,5])

# %%
y = np.array([1,5,9])

# %%
x.mean() #mean is a funtion
# Out:
# 3.0

# %%
y.mean()
# Out:
# 5.0

# %%
x.shape #Noparentesis shape is a data attribute
# Out:
# (3,)

# %%
y.shape
# Out:
# (3,)

# %%
#Modules and Methods
import math

# %%
math.pi
# Out:
# 3.141592653589793

# %%
math.sqrt(10)
# Out:
# 3.1622776601683795

# %%
math.pi/2
# Out:
# 1.5707963267948966

# %%
math.sin(math.pi/2)
# Out:
# 1.0

# %%
from math import pi

# %%
import math

# %%
import numpy as np

# %%
math.sqrt
# Out:
# <function math.sqrt>

# %%
np.sqrt
# Out:
# <ufunc 'sqrt'>

# %%
math.sqrt(10)
# Out:
# 3.1622776601683795

# %%
np.sqrt(10)
# Out:
# 3.1622776601683795

# %%
np.sqrt([1,3,5])
# Out:
# array([1.        , 1.73205081, 2.23606798])

# %%
name="Amy"

# %%
type(name)
# Out:
# str

# %%
dir(name)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
# ...

# %%
dir(str)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
# ...

# %%
help(name.upper) #Here it is telling me what this method does
# Out:
# Help on built-in function upper:
#
# upper(...) method of builtins.str instance
#     S.upper() -> str
#
#     Return a copy of S converted to uppercase.

# %%
help(name.upper()) #I'm runing the method here
# Out:
# No Python documentation found for 'AMY'.
# Use help() to get the interactive help utility.
# Use help(str) for help on the str class.

# %%
#Numbers and basic calculations
#Integers (unlimited precision) ,
#Floating point numbers, and Complex
173+43
# Out:
# 216

# %%
136*34
# Out:
# 4624

# %%
136**34
# Out:
# 3469947344869626678764764944008828704623704329617982034142229090130722816

# %%
1244**342
# Out:
# ...

# %%
#Division
60/7
# Out:
# 8.571428571428571

# %%
15/7
# Out:
# 2.142857142857143

# %%
15//7 #Rounded number
# Out:
# 2

# %%
15/2.3
# Out:
# 6.521739130434783

# %%
_ #The latest value
# Out:
# 6.521739130434783

# %%
_*2.3
# Out:
# 15.0

# %%
10*2
# Out:
# 20

# %%
_ +5
# Out:
# 25

# %%
_**2
# Out:
# 625

# %%
#Factorial=n!=n.n.n.n.n.....
import math

# %%
math.factorial(3)
# Out:
# 6

# %%
math.factorial(4)
# Out:
# 24

# %%
#Random choice
import random

# %%
random.choice([2,44,55,66])
# Out:
# 2

# %%
random.choice([2,44,55,66]) #The type of the object doesnt matter
# Out:
# 2

# %%
random.choice(["aa","bb","cc"])
# Out:
# 'cc'

# %%
random.choice(["aa","bb","cc"])
# Out:
# 'cc'

# %%
random.choice(["aa","bb","cc"])
# Out:
# 'bb'

# %%
#Expressions and Booleans (or, and, not)
#Values of Booleans and their returns
#Boolean=True and False
type(True)
# Out:
# bool

# %%
type(False) #Capitalize
# Out:
# bool

# %%
#Boolean or and not
True or False
# Out:
# True

# %%
True or True
# Out:
# True

# %%
True or False
# Out:
# True

# %%
False or True
# Out:
# True

# %%
False or False
# Out:
# False

# %%
not False
# Out:
# True

# %%
not True
# Out:
# False

# %%
2<4
