# %%
#Extressions and Booleans
2<=2
# Out:
# True

# %%
2==2
# Out:
# True

# %%
2!=2
# Out:
# False

# %%
[2,3]==[3,3]
# Out:
# False

# %%
[3,3] is [2,3]
# Out:
# False

# %%
[3,3] is [3,3]
# Out:
# False

# %%
[2,3] is not [2,3] #2 objects
# Out:
# True

# %%
2.8 == 2
# Out:
# False

# %%
#Floating point of 2 is 2.0
2.0==2.0
# Out:
# True

# %%
#== tests whether objects have the same value, whereas is tests whether objects have the same identity.
